# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Fried-toofuu/music-data/blob/main/data_pipeline/notebooks/00_colab_setup_guide.ipynb)
#
# # Hướng dẫn Setup Môi trường Demo trên Google Colab
#
#
# Notebook này cung cấp đoạn mã tự động phát hiện thiết bị và tải các thành phần cần thiết.
#
# **CHỈ CẦN CHẠY CELL DƯỚI ĐÂY MỘT LẦN DUY NHẤT.**

# %%
import sys
import os

# 1. Kiểm tra môi trường
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    print("[1/3] Đang chạy trên Google Colab. Bắt đầu Setup...")
    
    # 2. Clone mã nguồn (Bỏ qua nếu đã tồn tại)
    if not os.path.exists('/content/music-data'):
        # !git clone https://github.com/Fried-toofuu/music-data.git /content/music-data
        print("[2/3] Đã tải source code thành công.")
    else:
        print("[2/3] Source code đã tồn tại.")
        
    # 3. Cài đặt các thư viện không có sẵn trên Colab
    print("[3/3] Đang cài đặt thư viện...")
    # !pip install -q polars av torchaudio datasets
    
    # 4. Định tuyến thư mục Root
    # Note: Nhờ thay đổi Github repo URL ở trên nếu sai
    SRC_DIR = '/content/music-data/data_pipeline'
    print(f"\nHoàn tất! Thư mục code hiện tại: {SRC_DIR}")
else:
    print("Đang chạy trên máy tính (Local). Bạn không cần cài đặt gì thêm.")
    SRC_DIR = os.path.abspath(os.path.join(os.getcwd(), '..'))
